# %% [markdown]
# # # Con los datos
# https://github.com/neo4j-contrib/northwind-neo4j

# %% [markdown]
# Muestra un gráfico de barras con el total de productos por categoria

# %%
import pandas as pd
import matplotlib.pyplot as plt

datos=pd.read_csv('products.csv')
df=datos[['unitsInStock','categoryID']]
df.head(25).plot.bar(x="unitsInStock", y="categoryID")
plt.show()

# %% [markdown]
# Muestra un gráfico circular con el precio medio por categoria

# %%
import pandas as pd
import matplotlib.pyplot as plt

def consumirCircular():
    datos=pd.read_csv('products.csv')
    df=datos[['unitsInStock','categoryID']]
    df.head(25).plot.pie(x="unitsInStock", y="categoryID")
    plt.show()

consumirCircular()

# %% [markdown]
# Muestra un histograma con los precios de los productos

# %%
import pandas as pd
import matplotlib.pyplot as plt

def  histograma():
    datos=pd.read_csv('products.csv')
    df=datos[['unitPrice','categoryID']]
    df.head(7).unitPrice.plot.hist()
    print(df.sample(5))
histograma()
# Out:
#     unitPrice  categoryID
# 36      26.00           8
# 74       7.75           1
# 7       40.00           2
# 13      23.25           7
# 22       9.00           5
